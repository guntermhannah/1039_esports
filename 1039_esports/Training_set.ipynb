# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matches_clean import clean_player_data

# %%
player_data = clean_player_data()
# Out:
# /root/code/jasminebz/1039_esports/1039_esports/matches_clean.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["obs_placed"] = df_clean["obs_placed"].replace(np.nan, 0)
# /root/code/jasminebz/1039_esports/1039_esports/matches_clean.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["roshans_killed"] = df_clean["roshans_killed"].replace(np.nan, 0)

# %%
player_data
# Out:
#           match_id  hero_id    account_id  net_worth  kills  deaths  \
# 0       6880961402       18  1.061968e+09       6055      0       1
# 1       6880961402       67  3.806631e+08       5183      6       1
# 2       6880961402       87  1.677427e+08       3941      0       1
# 3       6880961402       32  1.648819e+08       3908      3       1
# 4       6880961402        8  2.909714e+08       4478      1       1
# ...            ...      ...           ...        ...    ...     ...
# 517695  6882510702      104  4.426971e+08      12144      5       6
# 517697  6882510702       43  1.482639e+08      15540      6       4
# 517722  6882510405      121  3.640587e+08       8754      9       6
# 517723  6882510405       81  1.175120e+09      19718     15       5
# 517727  6882510405       26  8.578329e+08       8318      7      12
#
#         hero_damage  gold_per_min  assists  xp_per_min  last_hits  \
# 0              1737           582        8         546         56
# ...

# %%
player_data.corr()
# Out:
#                 match_id   hero_id  account_id  net_worth     kills    deaths  \
# match_id        1.000000 -0.009049    0.010717  -0.010910 -0.021125 -0.029874
# hero_id        -0.009049  1.000000   -0.004442  -0.085734 -0.042908  0.017777
# account_id      0.010717 -0.004442    1.000000   0.038530  0.059479  0.014682
# net_worth      -0.010910 -0.085734    0.038530   1.000000  0.714785 -0.364859
# kills          -0.021125 -0.042908    0.059479   0.714785  1.000000 -0.288723
# deaths         -0.029874  0.017777    0.014682  -0.364859 -0.288723  1.000000
# hero_damage    -0.030210 -0.024422    0.039765   0.695586  0.786308 -0.076667
# gold_per_min   -0.003278 -0.096633    0.056548   0.921537  0.720396 -0.462279
# assists        -0.026333  0.078170   -0.036946   0.265363  0.278721 -0.122991
# xp_per_min     -0.021318 -0.072738    0.067706   0.895117  0.760218 -0.360215
# last_hits      -0.005462 -0.136706    0.046542   0.841827  0.442509 -0.293399
# ...

# %%
abs(player_data.corr()["win"]).sort_v
# Out:
# match_id          0.001508
# hero_id           0.006735
# account_id        0.008540
# net_worth         0.503189
# kills             0.463087
# deaths            0.589328
# hero_damage       0.287077
# gold_per_min      0.527817
# assists           0.562166
# xp_per_min        0.530095
# last_hits         0.217144
# tower_damage      0.547349
# obs_placed        0.006236
# roshans_killed    0.007130
# isRadiant         0.116527
# win               1.000000
# Name: win, dtype: float64
